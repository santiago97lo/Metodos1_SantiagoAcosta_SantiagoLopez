# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.1,1.1,400)
h = 0.01

def derivada_progresiva(x,f,h):
    return (f(x+h)-f(x))/h

def derivada_central(f, x, h):
    return (f(x+h) - f(x-h)) / (2*h)

def f(x):
    return np.sqrt(np.tan(x))

def derivada_real(x):
    return (1/(np.cos(x)**2))/(2*np.sqrt(np.tan(x)))

# %%
plt.plot(x,derivada_central(f,x,h),c='darkred', linewidth=2)
plt.title("Función f '(x)", size=20, c='darkred')
plt.show()

# %%
plt.plot(x,derivada_real(x),c='darkred', linewidth=2)
plt.title("Función f '(x)", size=20, c='darkred')
plt.show()

# %%
plt.plot(x,np.abs(derivada_real(x)-derivada_central(f,x,h)), c='darkgreen', linewidth=2)
plt.title("Estimación del error en cada punto nodal respecto a la derivada central.", size=18, c='darkgreen')
plt.show()

# %%
plt.plot(x, derivada_pro(x,f,h),c='darkred', linewidth=2)
plt.title("Función f '(x)", size=20, c='darkred')
plt.show()

# %%
plt.plot(x,np.abs(derivada_real(x)-derivada_pro(x,f,h)), c='darkgreen', linewidth=2)
plt.title("Estimación del error en cada punto nodal respecto a la derivada progresiva.", size=18, c='darkgreen')
plt.show()

# %% [markdown]
# Según las graficas obtenidas de los errores en cada punto nodal se observa que la derivada progresiva refleja menos error a comparación de los datos obtenidos a partir de la derivada central. Por otra parte, estos metodos de derivación son una buena aproximación al resultado que se obtiene si se deriva analíticamente la funcion f(x).
